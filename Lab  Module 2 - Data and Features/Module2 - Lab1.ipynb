# %% [markdown]
# Escoja cualquier juego que usted conoce una cantidad decente. Podría ser el fútbol americano, fútbol, ​​ping-pong, roca-papel-tijeras, Yoruba Ayo, Liga de Leyendas, Dungeons and Dragons, su trabajo (si es divertido) Siempre y cuando usted está íntimamente familiarizado con él.
#
# Abra el archivo /DAT210x/Module2/assignment1.xls ubicado en el repo del curso. Si no tiene Excel, el documento tiene este aspecto:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Notice how the Type column can only be Numeric or Textual, and the Class column can only be Continuous, Ordinal, or Nominal.
#
# Assuming you wanted to create a dataset that would hold various statistics about players playing the game you choose, come up with at least seven features of various type and class.
#
#
# Observe cómo la columna Tipo sólo puede ser numérica o textual y la columna Clase sólo puede ser continua, ordinaria o nominal.
#
# Suponiendo que quería crear un conjunto de datos que contenga varias estadísticas sobre los jugadores que juegan el juego que elija, proponga al menos siete características de varios tipos y clases.
