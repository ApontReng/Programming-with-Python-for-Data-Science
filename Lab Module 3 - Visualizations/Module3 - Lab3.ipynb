# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab3
#
#
# El trigo entero es bastante saludable por lo que para esta tarea, seguirá utilizando el conjunto de datos de semillas de trigo. Como de costumbre, empiece abriendo el código de inicio ubicado en Module3 / assignment3.py y leyendo a través de él. Entonces, escriba el código que ...
#
# - Carga el dataset de semillas, ubicado en Module3 / Datasets / wheat.data 'en un dataframe. Usted debe ser muy bueno en hacer esto por ahora.
# - Gráfico de un diagrama de dispersión 3D utilizando las características de área, perímetro y asimetría. Asegúrese de etiquetar sus ejes y utilice el parámetro de pantalla opcional c = 'rojo'.
# - Grafique un diagrama de dispersión 3D utilizando las funciones de ancho, ranura y longitud. Asegúrese de etiquetar los ejes y use el parámetro de pantalla opcional c = 'verde'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
# Look pretty...

matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
df = pd.read_csv('wheat.data',index_col=0)

# %% [markdown]
# Create a new 3D subplot using figure `fig`, which we've defined for you below. Use that subplot to draw a 3D scatter plot using the `area`, `perimeter`, and `asymmetry` features. Be sure so use the optional display parameter `c='red'`, and also label your axes:

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection ='3d')

ax.set_xlabel('area')
ax.set_ylabel('perimeter')
ax.set_zlabel('aasymmetry')

ax.scatter(df.area,df.perimeter,df.asymmetry, c='red' , marker = '^')
plt.show()

# %% [markdown]
# Create another 3D subplot using fig. Then use the subplot to graph a 3D scatter plot of the `width`, `groove`, and `length` features. Be sure so use the optional display parameter `c='green'`, and be sure to label your axes:

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.set_xlabel('width')
ax.set_ylabel('groove')
ax.set_zlabel('length')

ax.scatter(df.width , df.groove , df.length , c ='green', marker = 'o')
plt.show()

# %% [markdown]
# Create a 2d scatter plot that graphs the `compactness` and `width` features:

# %%
# Display the graphs:
df.plot.scatter(x='compactness',y='width')
plt.show()
